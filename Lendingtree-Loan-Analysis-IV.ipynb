# %% [markdown]
# # Peer-to-peer Loan Data Analysis 💰 - IV

# %% [markdown]
# ### 📊 Exploratory Data Analysis & Visualisations by `Stacking Plots`

# %% [markdown]
# Just like we can stack commands from both Seaborn and Matplotlib to create a visually appealing chart, we can also stack multiple plots on top of each other.
#
# We may want to use this technique to:
# * Stack complementary plots or
# * Plot multiple distributions together on the same axes.

# %% [markdown]
# ## Scenario - 1:
# ### `Rug Plot` with Histograms

# %% [markdown]
# * One limitation of **histograms** is that they obscure the mass of data within the bins, so **we lose sight of the individual values.**
#
# * So, a **histogram** is an **aggregated plot**, and it's **complemented well by** a **disaggregated plot** - one that **shows all the individual values.**
#
# * One option we have is a `rug plot`.
#
# * A **rugplot** displays all the individual values on the specified axis, typically at the base of the histogram, so we get the benefit of visualizing the shape of the distribution and the location of the individual data points.
#
# * This is a Seaborn plot function. We can just stack this plot right on top of the previous plot.

# %% [markdown]
# **Goal:**
#
# * We are interested in characterizing the different features present in the dataset. It contains both:
#
#     * Features of **each person**, like their **occupation** and **loan history**, and
#
#     * Features of the **individual loans** in the dataset, like the **loan amount** and **interest rate.**
#
# **Task:**
#
# Based on some previous analysis, we know that the **loan amount** feature in our dataset has some interesting patterns.
# We want to visualize this data using a **histogram** and **rugplot** to explain its unique properties to our clients.
# This visualization will help them identify and price common loan products based on what their competitors may offer.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("loan_data.csv")

# %%
df.head()
# Out:
#                           emp_title  emp_length state homeownership  \
# 0          administrative assistant           0    FL          RENT
# 1                   sole proprietor          10    MN           OWN
# 2                  pension ananlyst          10    MD           OWN
# 3  director of corporate operations           0    MN      MORTGAGE
# 4                        dispatcher           3    TX          RENT
#
#    debt_to_income  annual_income  open_credit_lines  total_credit_limit  \
# 0           22.51        32000.0                  4               22984
# 1            2.99        45000.0                  5              203255
# 2           21.07        90000.0                 19              154848
# 3           12.28       130000.0                 23              296496
# 4           28.97        65000.0                 28              156207
#
#    total_credit_utilized  total_debit_limit  loan_amount  interest_rate  \
# ...

# %% [markdown]
# * We will create a rug plot and stack it on top of our existing histogram:

# %%
sns.histplot(df, x="loan_amount", binwidth=5000, color="RosyBrown", kde=True)  #aggregated
sns.rugplot(df, x="loan_amount", color="MediumSeaGreen")   #disaggregated

plt.title("Distribution of Loan Amount", fontsize=14)
plt.xlabel("Loan Amount")
plt.ylabel("")
plt.grid(axis="y", linestyle="--", alpha=0.4)
plt.show()

# %% [markdown]
# *The rug plot is a disaggregated plot that gives us insight into how the individual values are positioned within the aggregated distribution shown by the histogram.*

# %% [markdown]
# ## Scenario - 2:
# ### `Strip Plot` with Box plots

# %% [markdown]
# * We can create a similar effect for a box plot using a strip plot.
#
# * The **different points** represent the **individual values**, just like the ticks in a rug plot.

# %% [markdown]
# **Goal:**
# * We are interested in characterizing the different features present in the dataset. It contains both:
#     * Features of **each person**, like their **occupation** and **loan history**, and
#     * Features of the **individual loans** in the dataset, like the **loan amount** and **interest rate.**
#
# **Task:**
# * Create Box plots with Strip plots to understand the distribution of loan amounts by different grades.

# %%
plt.figure(figsize=(8,8))
sns.boxplot(df, x="grade", y="loan_amount", palette="RdYlGn_r")
sns.stripplot(df, x="grade", y="loan_amount", color="gray", jitter=0.2, size=3)
sns.despine()
plt.title("Distribution of Loan Amount by Grade")
plt.xlabel("Grade")
plt.ylabel("Loan Amount")
plt.grid(axis="y", linestyle="--", color="grey", alpha=0.4)
plt.show()
# Out:
# /var/folders/6h/h489k5ln6r93tz_q7ssx2hj00000gn/T/ipykernel_12531/3809474418.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(df, x="grade", y="loan_amount", palette="RdYlGn_r")

# %% [markdown]
# * This type of plot shows us the value when we combine the individual data points with the aggregated box plots.
#
# * In this case, you can see there's a lot more observations in the data for grades A through D and fewer observations for grades E through G. We can plot many different combinations of charts on top of each other.

# %% [markdown]
# ## Scenario - 3:
# ### Overlaying `Histograms` on Same Chart

# %% [markdown]
# We may be interested in plotting multiple histograms together on the same axes to compare distributions.
#
# * For example, if we're interested in comparing the distribution of loan amounts for A and D grade loans, we can first filter these into two separate data frames: A is only for when the grade matches A, and D is only for when the grade matches D.
#
# * Then, we can just go ahead and reuse the histogram code, changing this data frame to A's only, plus add another hist plot. Just like we stacked the rug plot on top here, we can just stack another histogram here too, this time for D's only. We can keep all the same parameters except the color, which you can keep as the default blue for the second histogram.

# %%
# Plotting multiple distributions - loan amounts for Grade A to D loans
as_only = df[df["grade"] == "A"]
ds_only = df[df["grade"] == "D"]

# %%
sns.histplot(as_only, x="loan_amount", color="RosyBrown", binwidth=5000, kde=True)
sns.histplot(ds_only, x="loan_amount", binwidth=5000, kde=True)

plt.title("Distribution of Loan Amount", fontsize=14)
plt.xlabel("Loan Amount")
plt.ylabel("")
plt.grid(axis="y", linestyle="--", alpha=0.4)
plt.show()

# %% [markdown]
# *So we can see the D loans have a less skewed distribution, and for the most part, A loans appear to be more common since there are only a few bins where D loans outnumber A's in the 25,000 to 30,000 range.*
#
# * Since we have two plots, we could call `plot.show()` twice to see each of them individually if we like.

# %%
sns.histplot(as_only, x="loan_amount", color="RosyBrown", binwidth=5000, kde=True)
plt.title("Distribution of Loan Amount for 'A' Grade Loans", fontsize=14)
plt.xlabel("Loan Amount")
plt.ylabel("")
plt.grid(axis="y", linestyle="--", alpha=0.4)
plt.show()

sns.histplot(ds_only, x="loan_amount", binwidth=5000, kde=True)
plt.title("Distribution of Loan Amount for 'D' Grade Loans", fontsize=14)
plt.xlabel("Loan Amount")
plt.ylabel("")
plt.ylim(0,200)
plt.grid(axis="y", linestyle="--", alpha=0.4)
plt.show()
